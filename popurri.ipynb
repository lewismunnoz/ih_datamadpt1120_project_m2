# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diamonds = pd.read_csv('/home/lewis/Desktop/ironhack/ih_datamadpt1120_project_m2/data/diamonds_train.csv')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# [40455 rows x 10 columns]

# %%
sns.barplot(x="color",
           y="price",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax = sns.regplot(x='carat', y='price', data=diamonds)

# %%
diamonds['size'] = diamonds['x'] * diamonds['y'] * diamonds['z']

diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
#              size
# 0      197.096725
# ...

# %%
diamonds['area'] = diamonds['x'] * diamonds['y'] 
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# ...

# %%
var = ['carat', 'size']

sns.lmplot(x="carat",
           y="price",
           data=diamonds)

# %%
var = ['carat', 'size']

sns.lmplot(x="carat",
           y="price",
           data=diamonds)

# %%
sns.lmplot(x="size",
           y="price",
           data= diamonds,
           fit_reg= False)

# %%
sns.distplot(diamonds['carat'])
# Out:
# /home/lewis/miniconda3/envs/ironhack_env/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='carat', ylabel='Density'>

# %%
diamonds.carat.unique()
# Out:
# array([1.21, 0.32, 0.71, 0.41, 1.02, 1.52, 1.01, 0.31, 1.14, 0.44, 0.93,
#        1.51, 1.65, 1.5 , 0.43, 0.38, 0.85, 1.53, 1.54, 0.3 , 1.3 , 1.  ,
#        0.9 , 1.55, 1.16, 0.35, 0.97, 1.19, 0.7 , 0.8 , 2.  , 0.5 , 0.51,
#        1.04, 0.64, 0.78, 0.52, 0.33, 0.47, 1.59, 0.34, 0.74, 1.08, 0.79,
#        1.33, 0.58, 1.22, 1.62, 0.55, 1.64, 1.1 , 1.03, 0.56, 1.13, 0.91,
#        1.24, 2.3 , 0.27, 0.36, 1.77, 1.06, 1.27, 0.92, 2.01, 1.83, 0.23,
#        0.77, 2.07, 1.11, 1.56, 0.96, 2.25, 1.18, 1.72, 0.59, 0.57, 0.72,
#        0.4 , 0.42, 1.36, 1.15, 0.54, 1.86, 1.41, 0.75, 2.22, 1.23, 0.88,
#        1.25, 0.28, 1.82, 1.37, 1.2 , 1.05, 0.39, 0.6 , 0.76, 0.25, 0.73,
#        0.53, 0.63, 2.53, 0.65, 0.62, 1.4 , 1.7 , 0.83, 1.17, 0.46, 1.26,
#        1.58, 2.13, 0.24, 1.07, 2.04, 0.45, 1.09, 2.05, 1.31, 0.29, 0.84,
#        1.12, 0.81, 2.75, 0.22, 0.66, 1.74, 1.57, 1.29, 1.69, 0.49, 2.24,
#        2.02, 0.61, 1.32, 1.87, 0.37, 0.67, 1.73, 0.82, 1.46, 1.71, 0.26,
# ...

# %%
diamonds.clarity.unique()
# Out:
# array(['VS2', 'VS1', 'SI1', 'SI2', 'IF', 'VVS1', 'VVS2', 'I1'],
#       dtype=object)

# %%
diamonds.depth.unique()
# Out:
# array([62.4, 63. , 65.5, 63.8, 60.5, 61.2, 65.2, 62.3, 61.8, 61.7, 58. ,
#        60.1, 61.6, 57.5, 62.1, 60.8, 61.9, 60.7, 61. , 62. , 61.3, 62.9,
#        63.2, 61.1, 62.5, 60.4, 60.2, 63.5, 60.3, 62.2, 55.2, 59.8, 62.6,
#        63.4, 63.9, 63.7, 61.5, 59.6, 63.3, 64.8, 62.7, 58.8, 59.7, 62.8,
#        65.3, 57.8, 59.4, 58.7, 61.4, 64.3, 64.6, 60.9, 63.6, 57.4, 63.1,
#        60. , 60.6, 58.9, 56.6, 58.6, 59.1, 59.5, 59.2, 43. , 57.6, 59.3,
#        64.1, 58.5, 59.9, 70.6, 64.7, 59. , 70.1, 64.5, 64. , 57.9, 58.1,
#        65.1, 66.7, 64.2, 58.4, 57.7, 64.4, 66. , 70.5, 58.2, 55. , 65. ,
#        67. , 56.5, 58.3, 65.8, 65.4, 69.8, 64.9, 57.3, 55.8, 65.6, 56.7,
#        68.6, 66.5, 65.7, 68.3, 66.2, 66.1, 71.6, 66.4, 56.2, 68. , 67.7,
#        67.8, 56.9, 56.1, 70.2, 44. , 67.6, 56.8, 67.3, 66.3, 66.8, 67.4,
#        66.9, 68.7, 56.3, 67.9, 65.9, 56.4, 68.2, 54.6, 57. , 57.2, 67.2,
#        70.8, 55.6, 53.4, 56. , 54.2, 54. , 66.6, 57.1, 67.5, 68.9, 67.1,
# ...

# %%
diamonds.color.unique()
# Out:
# array(['J', 'H', 'G', 'D', 'F', 'E', 'I'], dtype=object)

# %%
diamonds.clarity.unique()
# Out:
# array(['VS2', 'VS1', 'SI1', 'SI2', 'IF', 'VVS1', 'VVS2', 'I1'],
#       dtype=object)

# %%
described_clarity = {
 
    'included': ['I1'],
    'internally_flawless': ['IF'],
    'very_slightly_included': ['VS2', 'VS1'],
    'very_very_slightly_included': ['VVS1', 'VVS2'],
    'slightly_included': ['SI1', 'SI2']
}

described_color = {
    "colorless": ["D", "E", "F"],
    "near_colorless": ["G", "H"],
    "slightly_tinted": ["I", "J"]
}

# %%
diamonds['described_clarity'] = [key for clarity in diamonds.clarity for key, item in described_clarity.items() if clarity in item]
diamonds['described_color'] = [key for color in diamonds.color for key, item in described_color.items() if color in item]

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# ...

# %%
sns.barplot(x="described_color",
           y="price",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='described_color', ylabel='price'>

# %%
sns.barplot(x="described_clarity",
           y="price",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='described_clarity', ylabel='price'>

# %%
sns.barplot(x="carat",
           y="price",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
diamonds.carat.unique()
# Out:
# array([1.21, 0.32, 0.71, 0.41, 1.02, 1.52, 1.01, 0.31, 1.14, 0.44, 0.93,
#        1.51, 1.65, 1.5 , 0.43, 0.38, 0.85, 1.53, 1.54, 0.3 , 1.3 , 1.  ,
#        0.9 , 1.55, 1.16, 0.35, 0.97, 1.19, 0.7 , 0.8 , 2.  , 0.5 , 0.51,
#        1.04, 0.64, 0.78, 0.52, 0.33, 0.47, 1.59, 0.34, 0.74, 1.08, 0.79,
#        1.33, 0.58, 1.22, 1.62, 0.55, 1.64, 1.1 , 1.03, 0.56, 1.13, 0.91,
#        1.24, 2.3 , 0.27, 0.36, 1.77, 1.06, 1.27, 0.92, 2.01, 1.83, 0.23,
#        0.77, 2.07, 1.11, 1.56, 0.96, 2.25, 1.18, 1.72, 0.59, 0.57, 0.72,
#        0.4 , 0.42, 1.36, 1.15, 0.54, 1.86, 1.41, 0.75, 2.22, 1.23, 0.88,
#        1.25, 0.28, 1.82, 1.37, 1.2 , 1.05, 0.39, 0.6 , 0.76, 0.25, 0.73,
#        0.53, 0.63, 2.53, 0.65, 0.62, 1.4 , 1.7 , 0.83, 1.17, 0.46, 1.26,
#        1.58, 2.13, 0.24, 1.07, 2.04, 0.45, 1.09, 2.05, 1.31, 0.29, 0.84,
#        1.12, 0.81, 2.75, 0.22, 0.66, 1.74, 1.57, 1.29, 1.69, 0.49, 2.24,
#        2.02, 0.61, 1.32, 1.87, 0.37, 0.67, 1.73, 0.82, 1.46, 1.71, 0.26,
# ...

# %%
pd.cut(diamonds['carat'], 20)
# Out:
# 0         (1.06, 1.275]
# 1        (0.196, 0.415]
# 2         (0.63, 0.845]
# 3        (0.196, 0.415]
# 4         (0.845, 1.06]
#               ...
# 40450     (1.275, 1.49]
# 40451     (1.92, 2.135]
# 40452     (0.845, 1.06]
# 40453    (0.196, 0.415]
# 40454     (1.06, 1.275]
# Name: carat, Length: 40455, dtype: category
# Categories (20, interval[float64]): [(0.196, 0.415] < (0.415, 0.63] < (0.63, 0.845] < (0.845, 1.06] ... (3.64, 3.855] < (3.855, 4.07] < (4.07, 4.285] < (4.285, 4.5]]

# %%
pd.cut(diamonds['carat'], 21).unique()
# Out:
# [(1.019, 1.224], (0.196, 0.405], (0.61, 0.814], (0.405, 0.61], (1.429, 1.633], ..., (3.067, 3.271], (3.271, 3.476], (3.476, 3.681], (4.09, 4.295], (4.295, 4.5]]
# Length: 20
# Categories (20, interval[float64]): [(0.196, 0.405] < (0.405, 0.61] < (0.61, 0.814] < (0.814, 1.019] ... (3.476, 3.681] < (3.886, 4.09] < (4.09, 4.295] < (4.295, 4.5]]

# %%
diamonds['carat_range'] = pd.cut(diamonds['carat'], 21)

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# ...

# %%
sns.barplot(x="carat_range",
           y="price",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='carat_range', ylabel='price'>

# %%
sns.barplot(x="carat_range",
           y="size",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='carat_range', ylabel='size'>

# %%
sns.barplot(x="carat_range",
           y="depth",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='carat_range', ylabel='depth'>

# %%
sns.barplot(x="carat_range",
           y="size",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='carat_range', ylabel='size'>

# %%
sns.barplot(x="carat_range",
           y="area",
           data= diamonds)
# Out:
# <AxesSubplot:xlabel='carat_range', ylabel='area'>

# %%
diamonds.groupby(['carat_range', 'described_color', 'described_clarity'])[['price']].mean().reset_index()
# Out:
#         carat_range  described_color            described_clarity  \
# 0    (0.196, 0.405]        colorless                     included
# 1    (0.196, 0.405]        colorless          internally_flawless
# 2    (0.196, 0.405]        colorless            slightly_included
# 3    (0.196, 0.405]        colorless       very_slightly_included
# 4    (0.196, 0.405]        colorless  very_very_slightly_included
# ..              ...              ...                          ...
# 310    (4.295, 4.5]  slightly_tinted                     included
# 311    (4.295, 4.5]  slightly_tinted          internally_flawless
# 312    (4.295, 4.5]  slightly_tinted            slightly_included
# 313    (4.295, 4.5]  slightly_tinted       very_slightly_included
# 314    (4.295, 4.5]  slightly_tinted  very_very_slightly_included
#
#             price
# 0      595.294118
# 1     1018.027682
# 2      647.543836
# 3      786.537888
# 4      853.877798
# ..            ...
# 310  18531.000000
# ...

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1       0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2       0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3       0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4       1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 40450   1.34      Ideal     G     VS1   62.7   57.0  10070  7.10  7.04  4.43
# 40451   2.02       Good     F     SI2   57.1   60.0  12615  8.31  8.25  4.73
# 40452   1.01      Ideal     H     SI1   62.7   56.0   5457  6.37  6.42  4.01
# 40453   0.33      Ideal     J     VS1   61.9   54.3    456  4.45  4.47  2.76
# 40454   1.24      Ideal     I     SI1   62.0   58.0   6232  6.83  6.88  4.25
#
# ...

# %%
diamonds.to_csv('diamonds_ok.csv', index = False)
